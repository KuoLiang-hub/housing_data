# %%
import pandas as pd
import matplotlib as plt

# %%
north_jersey = ["Date","Bergen County","Middlesex County","Essex County","Hudson County","Monmouth County","Union County","Passaic County","Morris County", "Mercer County","Somerset County","Sussex County","Hunterdon County","Warren County","Salem County"]
south_jersey = ["Date","Ocean County","Camden County","Burlington County", "Gloucester County","Atlantic County","Cumberland County","Cape May County",]

nj_data = pd.read_csv('./NJ_County.csv', usecols=north_jersey, index_col='Date')
nj_data2 = pd.read_csv('./NJ_County.csv', usecols=south_jersey, index_col='Date')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 north_jersey = ["Bergen County","Middlesex County","Essex County","Hudson County","Monmouth County","Union County","Passaic County","Morris County", "Mercer County","Somerset County","Sussex County","Hunterdon County","Warren County","Salem County"]
#       2 south_jersey = ["Date","Ocean County","Camden County","Burlington County", "Gloucester County","Atlantic County","Cumberland County","Cape May County",]
# ----> 4 nj_data = pd.read_csv('./NJ_County.csv', usecols=north_jersey, index_col='Date')
#       5 nj_data2 = pd.read_csv('./NJ_County.csv', usecols=south_jersey, index_col='Date')
#
# File c:\Users\liang\anaconda3\envs\example_env\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
# ...

# %%
# check the price
nj_data.plot(figsize=(15, 8), grid='y', title="North Jersey")
# Out:
# <Axes: xlabel='Date'>

# %%
# check the price
nj_data2.plot(figsize=(15, 8), grid='y', title="South Jersey")
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# # Compare the growth rate
# (nj_data / nj_data.iloc[0]).plot(figsize=(10,5))

# %%
dcsim_data = pd.read_csv('DC_vs_Surrounds_simpley.csv', index_col='Date')

# %%
dcsim_data.plot(figsize=(10, 5),grid='y')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### county map

# %% [markdown]
# ![nj county img](./pics/NJ-County-Map.jpg)
